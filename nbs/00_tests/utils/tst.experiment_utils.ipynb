# %%
# hide
# default_exp tests.tools.test_experiment_utils
from nbdev.showdoc import *
from block_types.utils.nbdev_utils import nbdev_setup, TestRunner

nbdev_setup ()
tst = TestRunner (targets=['dummy'])

# %% [markdown]
# # Test experiment utils

# %%
# export
import pytest
import pandas as pd
import os
import joblib
from IPython.display import display
from block_types.utils.nbdev_utils import md

from hpsearch.tools.experiment_utils import *
from hpsearch.examples.dummy_experiment_manager import (DummyExperimentManager, 
                                                        run_multiple_experiments)

# %%
##export
#@pytest.fixture (name='init_em')
#def init_em_fixture():
#    return init_em()
