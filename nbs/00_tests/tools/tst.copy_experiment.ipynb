# %%
# hide
# default_exp tests.tools.test_copy_experiment
from nbdev.showdoc import *
from block_types.utils.nbdev_utils import nbdev_setup, TestRunner

nbdev_setup ()
tst = TestRunner (targets=['dummy'])

# %% [markdown]
# # Test copy_experiment

# %%
# export
import pytest
import pandas as pd
import os
import joblib
from IPython.display import display
from block_types.utils.nbdev_utils import md

from hpsearch.tools.copy_experiment import *
from hpsearch.examples.complex_dummy_experiment_manager import generate_data, init_em

# %%
##export
#@pytest.fixture (name='init_em')
#def init_em_fixture():
#    return init_em()
