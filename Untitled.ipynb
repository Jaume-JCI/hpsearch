# %%
pwd
# Out:
# '/home/jcidatascience/jaume/workspace/other/jaume_nbdev'

# %%
from hpsearch.example_wrapper import ExampleExperimentManager

# %%
em = ExampleExperimentManager ()
parameters = dict(my_third=3.0)
other_parameters = dict()
em.grid_search (log_message='single input, learning rate and regularization grid search, 500 epochs',
        parameters_multiple_values=dict(my_first=[0.6, 0.3], my_second=[1.2, 2.3, 4.0]),
        parameters_single_value = parameters,
        other_parameters=other_parameters,
        nruns=1)
# Out:
# experiment script: <ipython-input-6-8fc501477ce0>, line: 4
# experiment script: <ipython-input-6-8fc501477ce0>, line: 4
# processing hyper-parameter 0 out of 6
# processing hyper-parameter 0 out of 6
# doing run 0 out of 1
# doing run 0 out of 1
# single input, learning rate and regularization grid search, 500 epochs
# running experiment 0
# single input, learning rate and regularization grid search, 500 epochs
# running experiment 0
# run number: 0
# run number: 0
#
# parameters:
# 	my_first=0.6,
# 	my_second=1.2,
# 	my_third=3.0
#
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# time spent for evaluation: 3.695487976074219e-05
#
# parameters:
# 	my_first=0.6,
# 	my_second=1.2,
# 	my_third=3.0
#
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# time spent for evaluation: 3.695487976074219e-05
# 0 - my_score: -1.8
# 0 - my_score: -1.8
# finished experiment 0
# finished experiment 0
# processing hyper-parameter 1 out of 6
# processing hyper-parameter 1 out of 6
# doing run 0 out of 1
# single input, learning rate and regularization grid search, 500 epochs
# running experiment 1
# run number: 0
# doing run 0 out of 1
# single input, learning rate and regularization grid search, 500 epochs
# running experiment 1
# run number: 0
#
# parameters:
# 	my_first=0.6,
# 	my_second=2.3,
# 	my_third=3.0
#
#
# parameters:
# 	my_first=0.6,
# 	my_second=2.3,
# 	my_third=3.0
#
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# time spent for evaluation: 3.0517578125e-05
# time spent for evaluation: 3.0517578125e-05
# 0 - my_score: -0.7000000000000002
# 0 - my_score: -0.7000000000000002
# finished experiment 1
# finished experiment 1
# processing hyper-parameter 2 out of 6
# doing run 0 out of 1
# processing hyper-parameter 2 out of 6
# doing run 0 out of 1
# single input, learning rate and regularization grid search, 500 epochs
# single input, learning rate and regularization grid search, 500 epochs
# running experiment 2
# running experiment 2
# run number: 0
#
# parameters:
# 	my_first=0.6,
# 	my_second=4.0,
# 	my_third=3.0
#
# run number: 0
# script: <ipython-input-6-8fc501477ce0>, line number: 4
#
# parameters:
# 	my_first=0.6,
# 	my_second=4.0,
# 	my_third=3.0
#
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# time spent for evaluation: 0.0002193450927734375
# 0 - my_score: 1.0
# time spent for evaluation: 0.0002193450927734375
# finished experiment 2
# 0 - my_score: 1.0
# finished experiment 2
# processing hyper-parameter 3 out of 6
# processing hyper-parameter 3 out of 6
# doing run 0 out of 1
# doing run 0 out of 1
# single input, learning rate and regularization grid search, 500 epochs
# running experiment 3
# single input, learning rate and regularization grid search, 500 epochs
# run number: 0
# running experiment 3
# run number: 0
#
# parameters:
# 	my_first=0.3,
# 	my_second=1.2,
# 	my_third=3.0
#
#
# parameters:
# 	my_first=0.3,
# 	my_second=1.2,
# 	my_third=3.0
#
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# time spent for evaluation: 3.3855438232421875e-05
# time spent for evaluation: 3.3855438232421875e-05
# 0 - my_score: 3.5999999999999996
# 0 - my_score: 3.5999999999999996
# finished experiment 3
# finished experiment 3
# processing hyper-parameter 4 out of 6
# processing hyper-parameter 4 out of 6
# doing run 0 out of 1
# doing run 0 out of 1
# single input, learning rate and regularization grid search, 500 epochs
# running experiment 4
# run number: 0
#
# parameters:
# 	my_first=0.3,
# 	my_second=2.3,
# 	my_third=3.0
#
# single input, learning rate and regularization grid search, 500 epochs
# running experiment 4
# run number: 0
#
# parameters:
# 	my_first=0.3,
# 	my_second=2.3,
# 	my_third=3.0
#
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# time spent for evaluation: 3.1948089599609375e-05
# time spent for evaluation: 3.1948089599609375e-05
# 0 - my_score: 6.8999999999999995
# 0 - my_score: 6.8999999999999995
# finished experiment 4
# finished experiment 4
# processing hyper-parameter 5 out of 6
# processing hyper-parameter 5 out of 6
# doing run 0 out of 1
# single input, learning rate and regularization grid search, 500 epochs
# running experiment 5
# run number: 0
# doing run 0 out of 1
# single input, learning rate and regularization grid search, 500 epochs
# running experiment 5
# run number: 0
#
# parameters:
# 	my_first=0.3,
# 	my_second=4.0,
# 	my_third=3.0
#
#
# parameters:
# 	my_first=0.3,
# 	my_second=4.0,
# 	my_third=3.0
#
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# script: <ipython-input-6-8fc501477ce0>, line number: 4
# time spent for evaluation: 3.2901763916015625e-05
# time spent for evaluation: 3.2901763916015625e-05
# 0 - my_score: 12.0
# 0 - my_score: 12.0
# finished experiment 5
# finished experiment 5
